# %% [markdown]
# # Gradient Based Optimization analysis

# %%
import glob
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
json_files = glob.glob("D:/Data/2018-05-25-16-39-47-21-SirArthur_DyingTriboddium_Deb/*.json")

# %%
timepoints = [int(name[name.rfind('_')+1:name.find(".json")]) for name in json_files]
(timepoints,json_files) = zip(*sorted(zip(timepoints, json_files)))

# %%
modes = 66
zerns = np.zeros((len(timepoints),modes));
for i,f in enumerate(json_files):
    with open(f) as json_data:
        data = json.load(json_data)
        zerns[i] = [data[0][j] for j in range(0,modes)]
#print(zerns[0])

# %%
plt.plot(zerns[:,4])
plt.ylabel("Deffocus Coeff");
plt.xlabel("Time point");

# %%
json_files = glob.glob("Y:/Deb/2018-05-25-15-15-22-90-SirArthur_FirstTriboddium_Deb/*.json")

# %%
timepoints = [int(name[name.rfind('_')+1:name.find(".json")]) for name in json_files]
(timepoints,json_files) = zip(*sorted(zip(timepoints, json_files)))

# %%
modes = 66
zerns = np.zeros((len(timepoints),modes));
for i,f in enumerate(json_files):
    with open(f) as json_data:
        data = json.load(json_data)
        zerns[i] = [data[0][j] for j in range(0,modes)]
#print(zerns[0])

# %%
plt.plot(zerns[:,4])
plt.ylabel("Deffocus Coeff");
plt.xlabel("Time point");

# %% [markdown]
# Gradient based optimization cant find a plateau
